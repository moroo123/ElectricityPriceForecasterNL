# %% [markdown]
# # Model Training: XGBoost Price Forecasting
#
# This notebook demonstrates how to use the feature pipeline to train an XGBoost model for electricity price forecasting.

# %%
import pandas as pd
import numpy as np
import sys
from pathlib import Path

# Add src to path
sys.path.append('../src')

from utils.preprocessing import (
    create_merged_dataset,
    split_train_val_test,
    handle_missing_values
)
from features.pipeline import TimeSeriesFeatureEngine
from models.train import (
    train_xgboost_model,
    train_baseline_model,
    evaluate_model,
    get_feature_importance,
    save_model
)
from models.baselines import NaivePersistence

# Plotly for interactive visualizations
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# %% [markdown]
# ## 1. Load and Prepare Data

# %%
# Load merged dataset from cache
df = create_merged_dataset(db_path="../data/cache.db")

print(f"Dataset shape: {df.shape}")
print(f"Date range: {df.index.min()} to {df.index.max()}")
print(f"\nColumns: {df.columns.tolist()}")

df.head()
# Out:
# Dataset shape: (26305, 6)
# Date range: 2022-01-01 00:00:00+01:00 to 2025-01-01 00:00:00+01:00
#
# Columns: ['price', 'load_forecast', 'actual_load', 'wind_onshore', 'wind_offshore', 'solar']
#                             price  load_forecast  actual_load  wind_onshore  \
# timestamp
# 2022-01-01 00:00:00+01:00  124.70     11532.1925   10374.1425       2646.25
# 2022-01-01 01:00:00+01:00  124.70     11085.1050   10249.9175       2419.75
# 2022-01-01 02:00:00+01:00  134.00     10805.7575    9907.0350       2161.75
# 2022-01-01 03:00:00+01:00   58.80     10676.2475    9782.3050       1954.75
# 2022-01-01 04:00:00+01:00   37.67     10643.9175    9589.5250       1706.75
#
#                            wind_offshore  solar
# timestamp
# 2022-01-01 00:00:00+01:00        1352.75    0.0
# 2022-01-01 01:00:00+01:00        1307.50    0.0
# 2022-01-01 02:00:00+01:00        1234.75    0.0
# 2022-01-01 03:00:00+01:00        1129.25    0.0
# 2022-01-01 04:00:00+01:00        1044.00    0.0

# %%
# Check for missing values
missing = df.isnull().sum()
print("Missing values per column:")
print(missing[missing > 0])
# Out:
# Missing values per column:
# load_forecast     1
# actual_load       1
# wind_onshore     25
# wind_offshore    25
# solar            25
# dtype: int64

# %%
# Handle missing values (forward fill with limit)
df_clean = handle_missing_values(df, strategy='forward_fill', limit=24)

# Drop any remaining NaN rows
df_clean = df_clean.dropna()

print(f"Clean dataset shape: {df_clean.shape}")
# Out:
# Clean dataset shape: (26305, 6)

# %% [markdown]
# ## 2. Split Data (Time-based)

# %%
# Time-based split (no shuffling!)
train_df, val_df, test_df = split_train_val_test(
    df_clean,
    train_end="2023-12-31",
    val_end="2024-06-30"
)
# Out:
# Train: 2022-01-01 00:00:00+01:00 to 2023-12-31 00:00:00+01:00 (17497 samples)
# Val:   2023-12-31 01:00:00+01:00 to 2024-06-30 00:00:00+02:00 (4367 samples)
# Test:  2024-06-30 01:00:00+02:00 to 2025-01-01 00:00:00+01:00 (4441 samples)

# %% [markdown]
# ## 3. Create Features

# %%
# Initialize feature engine
feature_engine = TimeSeriesFeatureEngine(
    target_col='price',
    forecast_horizon=24,
    feature_config={'scaler_type': 'robust'},
    price_lags=[0, 1, 2, 3, 6, 12, 24, 48, 144, 168],  # Add lag 0 and 144 for baselines + recent + weekly
    price_windows=[6, 12, 24, 168],             # Short-term + long-term windows
    load_lags=[1, 24, 168]                      # Recent + seasonal
)

print("Feature engine initialized")
# Out:
# Feature engine initialized

# %%
# Create features on the FULL dataset first, then split
# This ensures lag features have access to historical data
print("Creating features on full dataset...")
X_full, y_full = feature_engine.prepare_data(df_clean, create_target=True)

print(f"Full dataset: X={X_full.shape}, y={y_full.shape}")

# Now split the features based on the original time splits
train_end_date = pd.Timestamp("2023-12-31 23:00:00+01:00")
val_end_date = pd.Timestamp("2024-06-30 23:00:00+02:00")

# Split based on index
X_train = X_full[X_full.index <= train_end_date]
y_train = y_full[y_full.index <= train_end_date]

X_val = X_full[(X_full.index > train_end_date) & (X_full.index <= val_end_date)]
y_val = y_full[(y_full.index > train_end_date) & (y_full.index <= val_end_date)]

X_test = X_full[X_full.index > val_end_date]
y_test = y_full[y_full.index > val_end_date]

print(f"\nTrain: X={X_train.shape}, y={y_train.shape}")
print(f"Val:   X={X_val.shape}, y={y_val.shape}")
print(f"Test:  X={X_test.shape}, y={y_test.shape}")
# Out:
# Creating features on full dataset...
# Full dataset: X=(26281, 67), y=(26281,)
#
# Train: X=(17520, 67), y=(17520,)
# Val:   X=(4367, 67), y=(4367,)
# Test:  X=(4394, 67), y=(4394,)

# %%
# Handle NaN values appropriately
# For lag features, forward fill is better than filling with 0
# For other features, use 0

lag_cols = [col for col in X_train.columns if 'lag' in col.lower()]
other_cols = [col for col in X_train.columns if col not in lag_cols]

# Forward fill lag features (more reasonable than 0)
X_train.loc[:, lag_cols] = X_train[lag_cols].ffill().fillna(0)
X_val.loc[:, lag_cols] = X_val[lag_cols].ffill().fillna(0)
X_test.loc[:, lag_cols] = X_test[lag_cols].ffill().fillna(0)

# Fill other features with 0
X_train.loc[:, other_cols] = X_train[other_cols].fillna(0)
X_val.loc[:, other_cols] = X_val[other_cols].fillna(0)
X_test.loc[:, other_cols] = X_test[other_cols].fillna(0)

print(f"Total features created: {X_train.shape[1]}")
print(f"\nFeature names (first 20):")
print(X_train.columns.tolist()[:20])
# Out:
# Total features created: 67
#
# Feature names (first 20):
# ['load_forecast', 'actual_load', 'wind_onshore', 'wind_offshore', 'solar', 'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos', 'month_sin', 'month_cos', 'is_weekend', 'total_renewable', 'total_wind', 'residual_load', 'residual_load_pct', 'renewable_penetration', 'wind_onshore_ratio', 'wind_offshore_ratio', 'solar_ratio']

# %% [markdown]
# ## 4. Train XGBoost Model

# %%
# Fit scaler on training data
feature_engine.fit(X_train, y_train)

# Transform features
X_train_scaled = feature_engine.transform(X_train)
X_val_scaled = feature_engine.transform(X_val)
X_test_scaled = feature_engine.transform(X_test)

# %%
# Train model with early stopping
model = train_xgboost_model(
    X_train_scaled,
    y_train,
    X_val_scaled,
    y_val,
    params={
        'learning_rate': 0.05,
        'max_depth': 6,
        'min_child_weight': 3,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
    },
    n_estimators=1000,
    early_stopping_rounds=50,
    verbose=True
)
# Out:
# [0]	validation_0-rmse:118.27024	validation_1-rmse:103.65035
# [1]	validation_0-rmse:113.46519	validation_1-rmse:99.23352
# [2]	validation_0-rmse:109.00440	validation_1-rmse:95.62522
# [3]	validation_0-rmse:104.84554	validation_1-rmse:91.66255
# [4]	validation_0-rmse:100.85155	validation_1-rmse:88.06930
# [5]	validation_0-rmse:97.12713	validation_1-rmse:84.42352
# [6]	validation_0-rmse:93.49271	validation_1-rmse:80.82915
# [7]	validation_0-rmse:90.05641	validation_1-rmse:77.84960
# [8]	validation_0-rmse:86.81071	validation_1-rmse:74.58469
# [9]	validation_0-rmse:83.83056	validation_1-rmse:71.70913
# [10]	validation_0-rmse:80.98599	validation_1-rmse:69.24115
# [11]	validation_0-rmse:78.32550	validation_1-rmse:66.53434
# [12]	validation_0-rmse:75.76822	validation_1-rmse:64.13778
# [13]	validation_0-rmse:73.45132	validation_1-rmse:61.78048
# [14]	validation_0-rmse:71.25861	validation_1-rmse:60.03690
# [15]	validation_0-rmse:69.12983	validation_1-rmse:58.21390
# [16]	validation_0-rmse:67.12553	validation_1-rmse:56.28722
# [17]	validation_0-rmse:65.23541	validation_1-rmse:54.48978
# [18]	validation_0-rmse:63.52505	validation_1-rmse:52.71136
# [19]	validation_0-rmse:61.87652	validation_1-rmse:51.43768
# [20]	validation_0-rmse:60.31093	validation_1-rmse:49.77706
# [21]	validation_0-rmse:58.85313	validation_1-rmse:48.28629
# [22]	validation_0-rmse:57.45369	validation_1-rmse:46.89504
# [23]	validation_0-rmse:56.15610	validation_1-rmse:45.69825
# [24]	validation_0-rmse:54.89471	validation_1-rmse:44.89574
# [25]	validation_0-rmse:53.78541	validation_1-rmse:43.72549
# [26]	validation_0-rmse:52.65432	validation_1-rmse:43.09355
# [27]	validation_0-rmse:51.63658	validation_1-rmse:42.10374
# [28]	validation_0-rmse:50.71868	validation_1-rmse:41.26839
# [29]	validation_0-rmse:49.82235	validation_1-rmse:40.30944
# [30]	validation_0-rmse:48.98991	validation_1-rmse:39.44426
# [31]	validation_0-rmse:48.23119	validation_1-rmse:38.59764
# [32]	validation_0-rmse:47.51825	validation_1-rmse:37.90325
# [33]	validation_0-rmse:46.85657	validation_1-rmse:37.24775
# [34]	validation_0-rmse:46.20220	validation_1-rmse:36.54156
# [35]	validation_0-rmse:45.59434	validation_1-rmse:35.94175
# [36]	validation_0-rmse:45.04701	validation_1-rmse:35.37525
# [37]	validation_0-rmse:44.50366	validation_1-rmse:34.88791
# [38]	validation_0-rmse:43.90672	validation_1-rmse:34.51542
# [39]	validation_0-rmse:43.39510	validation_1-rmse:34.40094
# [40]	validation_0-rmse:42.89595	validation_1-rmse:34.20329
# [41]	validation_0-rmse:42.44729	validation_1-rmse:33.95341
# [42]	validation_0-rmse:41.95834	validation_1-rmse:33.60721
# [43]	validation_0-rmse:41.49293	validation_1-rmse:33.22093
# [44]	validation_0-rmse:41.05279	validation_1-rmse:33.03818
# [45]	validation_0-rmse:40.70479	validation_1-rmse:32.71204
# [46]	validation_0-rmse:40.30562	validation_1-rmse:32.48990
# [47]	validation_0-rmse:39.93327	validation_1-rmse:32.27867
# [48]	validation_0-rmse:39.58016	validation_1-rmse:32.17694
# [49]	validation_0-rmse:39.28776	validation_1-rmse:31.93194
# [50]	validation_0-rmse:38.96127	validation_1-rmse:31.79071
# [51]	validation_0-rmse:38.65380	validation_1-rmse:31.52442
# [52]	validation_0-rmse:38.37447	validation_1-rmse:31.35272
# [53]	validation_0-rmse:38.10293	validation_1-rmse:31.08332
# [54]	validation_0-rmse:37.81939	validation_1-rmse:30.97666
# [55]	validation_0-rmse:37.54765	validation_1-rmse:30.73526
# [56]	validation_0-rmse:37.23586	validation_1-rmse:30.56532
# [57]	validation_0-rmse:36.95933	validation_1-rmse:30.45155
# [58]	validation_0-rmse:36.67241	validation_1-rmse:30.27106
# [59]	validation_0-rmse:36.47210	validation_1-rmse:30.19939
# [60]	validation_0-rmse:36.23502	validation_1-rmse:30.12923
# [61]	validation_0-rmse:35.98722	validation_1-rmse:30.06440
# [62]	validation_0-rmse:35.82755	validation_1-rmse:29.93724
# [63]	validation_0-rmse:35.61827	validation_1-rmse:29.79819
# [64]	validation_0-rmse:35.42379	validation_1-rmse:29.68325
# [65]	validation_0-rmse:35.24399	validation_1-rmse:29.55811
# [66]	validation_0-rmse:35.02292	validation_1-rmse:29.51706
# [67]	validation_0-rmse:34.87421	validation_1-rmse:29.60102
# [68]	validation_0-rmse:34.70534	validation_1-rmse:29.56303
# [69]	validation_0-rmse:34.55441	validation_1-rmse:29.54180
# [70]	validation_0-rmse:34.42191	validation_1-rmse:29.56879
# [71]	validation_0-rmse:34.23237	validation_1-rmse:29.52577
# [72]	validation_0-rmse:34.05838	validation_1-rmse:29.48575
# [73]	validation_0-rmse:33.87342	validation_1-rmse:29.44878
# [74]	validation_0-rmse:33.74509	validation_1-rmse:29.50466
# [75]	validation_0-rmse:33.62590	validation_1-rmse:29.50696
# [76]	validation_0-rmse:33.49100	validation_1-rmse:29.41205
# [77]	validation_0-rmse:33.36463	validation_1-rmse:29.37275
# [78]	validation_0-rmse:33.23973	validation_1-rmse:29.34775
# [79]	validation_0-rmse:33.08351	validation_1-rmse:29.32607
# [80]	validation_0-rmse:32.95781	validation_1-rmse:29.30598
# [81]	validation_0-rmse:32.85610	validation_1-rmse:29.25457
# [82]	validation_0-rmse:32.73278	validation_1-rmse:29.22652
# [83]	validation_0-rmse:32.60130	validation_1-rmse:29.19841
# [84]	validation_0-rmse:32.49912	validation_1-rmse:29.19912
# [85]	validation_0-rmse:32.41553	validation_1-rmse:29.16821
# [86]	validation_0-rmse:32.26411	validation_1-rmse:29.10469
# [87]	validation_0-rmse:32.16064	validation_1-rmse:29.10065
# [88]	validation_0-rmse:32.03616	validation_1-rmse:29.03524
# [89]	validation_0-rmse:31.87511	validation_1-rmse:28.96982
# [90]	validation_0-rmse:31.75565	validation_1-rmse:29.00421
# [91]	validation_0-rmse:31.61541	validation_1-rmse:29.10519
# [92]	validation_0-rmse:31.53075	validation_1-rmse:29.08886
# [93]	validation_0-rmse:31.40944	validation_1-rmse:29.08950
# [94]	validation_0-rmse:31.30844	validation_1-rmse:29.03648
# [95]	validation_0-rmse:31.21983	validation_1-rmse:29.00101
# [96]	validation_0-rmse:31.10968	validation_1-rmse:28.95230
# [97]	validation_0-rmse:31.02294	validation_1-rmse:28.95352
# [98]	validation_0-rmse:30.91918	validation_1-rmse:28.91004
# [99]	validation_0-rmse:30.79232	validation_1-rmse:28.88814
# [100]	validation_0-rmse:30.70774	validation_1-rmse:28.86466
# [101]	validation_0-rmse:30.61612	validation_1-rmse:28.79579
# [102]	validation_0-rmse:30.53820	validation_1-rmse:28.78882
# [103]	validation_0-rmse:30.39249	validation_1-rmse:28.79118
# [104]	validation_0-rmse:30.31916	validation_1-rmse:28.78139
# [105]	validation_0-rmse:30.24170	validation_1-rmse:28.76606
# [106]	validation_0-rmse:30.17208	validation_1-rmse:28.68823
# [107]	validation_0-rmse:30.08979	validation_1-rmse:28.68663
# [108]	validation_0-rmse:30.02842	validation_1-rmse:28.69791
# [109]	validation_0-rmse:29.95236	validation_1-rmse:28.71383
# [110]	validation_0-rmse:29.89883	validation_1-rmse:28.79573
# [111]	validation_0-rmse:29.81958	validation_1-rmse:28.73137
# [112]	validation_0-rmse:29.75935	validation_1-rmse:28.75509
# [113]	validation_0-rmse:29.64332	validation_1-rmse:28.76034
# [114]	validation_0-rmse:29.55689	validation_1-rmse:28.75056
# [115]	validation_0-rmse:29.48973	validation_1-rmse:28.71590
# [116]	validation_0-rmse:29.43836	validation_1-rmse:28.69005
# [117]	validation_0-rmse:29.34483	validation_1-rmse:28.70057
# [118]	validation_0-rmse:29.25993	validation_1-rmse:28.64951
# [119]	validation_0-rmse:29.18312	validation_1-rmse:28.64840
# [120]	validation_0-rmse:29.12157	validation_1-rmse:28.64485
# [121]	validation_0-rmse:29.08171	validation_1-rmse:28.61900
# [122]	validation_0-rmse:28.97740	validation_1-rmse:28.60172
# [123]	validation_0-rmse:28.90045	validation_1-rmse:28.62327
# [124]	validation_0-rmse:28.79694	validation_1-rmse:28.54173
# [125]	validation_0-rmse:28.75093	validation_1-rmse:28.52469
# [126]	validation_0-rmse:28.66211	validation_1-rmse:28.50525
# [127]	validation_0-rmse:28.59247	validation_1-rmse:28.48832
# [128]	validation_0-rmse:28.50248	validation_1-rmse:28.52799
# [129]	validation_0-rmse:28.40289	validation_1-rmse:28.53915
# [130]	validation_0-rmse:28.35145	validation_1-rmse:28.53478
# [131]	validation_0-rmse:28.26406	validation_1-rmse:28.52756
# [132]	validation_0-rmse:28.23386	validation_1-rmse:28.56414
# [133]	validation_0-rmse:28.15412	validation_1-rmse:28.56342
# [134]	validation_0-rmse:28.10096	validation_1-rmse:28.56879
# [135]	validation_0-rmse:28.05373	validation_1-rmse:28.57098
# [136]	validation_0-rmse:27.97905	validation_1-rmse:28.52794
# [137]	validation_0-rmse:27.87525	validation_1-rmse:28.52401
# [138]	validation_0-rmse:27.78947	validation_1-rmse:28.53526
# [139]	validation_0-rmse:27.74828	validation_1-rmse:28.53412
# [140]	validation_0-rmse:27.68215	validation_1-rmse:28.49188
# [141]	validation_0-rmse:27.61761	validation_1-rmse:28.49130
# [142]	validation_0-rmse:27.58446	validation_1-rmse:28.48255
# [143]	validation_0-rmse:27.53682	validation_1-rmse:28.51514
# [144]	validation_0-rmse:27.47307	validation_1-rmse:28.55783
# [145]	validation_0-rmse:27.43104	validation_1-rmse:28.57811
# [146]	validation_0-rmse:27.39616	validation_1-rmse:28.55370
# [147]	validation_0-rmse:27.33317	validation_1-rmse:28.57931
# [148]	validation_0-rmse:27.28592	validation_1-rmse:28.58149
# [149]	validation_0-rmse:27.22179	validation_1-rmse:28.53437
# [150]	validation_0-rmse:27.14095	validation_1-rmse:28.52819
# [151]	validation_0-rmse:27.08160	validation_1-rmse:28.50598
# [152]	validation_0-rmse:27.05382	validation_1-rmse:28.49804
# [153]	validation_0-rmse:27.00915	validation_1-rmse:28.51141
# [154]	validation_0-rmse:26.95397	validation_1-rmse:28.52895
# [155]	validation_0-rmse:26.86377	validation_1-rmse:28.54984
# [156]	validation_0-rmse:26.81039	validation_1-rmse:28.54023
# [157]	validation_0-rmse:26.74170	validation_1-rmse:28.54946
# [158]	validation_0-rmse:26.68914	validation_1-rmse:28.55039
# [159]	validation_0-rmse:26.64649	validation_1-rmse:28.55606
# [160]	validation_0-rmse:26.61941	validation_1-rmse:28.57614
# [161]	validation_0-rmse:26.50516	validation_1-rmse:28.54335
# [162]	validation_0-rmse:26.46689	validation_1-rmse:28.56816
# [163]	validation_0-rmse:26.39669	validation_1-rmse:28.55329
# [164]	validation_0-rmse:26.35876	validation_1-rmse:28.55385
# [165]	validation_0-rmse:26.30806	validation_1-rmse:28.54542
# [166]	validation_0-rmse:26.23960	validation_1-rmse:28.53351
# [167]	validation_0-rmse:26.17701	validation_1-rmse:28.51683
# [168]	validation_0-rmse:26.13655	validation_1-rmse:28.54315
# [169]	validation_0-rmse:26.07208	validation_1-rmse:28.53695
# [170]	validation_0-rmse:26.03263	validation_1-rmse:28.54111
# [171]	validation_0-rmse:25.95171	validation_1-rmse:28.54321
# [172]	validation_0-rmse:25.91992	validation_1-rmse:28.51879
# [173]	validation_0-rmse:25.87447	validation_1-rmse:28.53350
# [174]	validation_0-rmse:25.84908	validation_1-rmse:28.50344
# [175]	validation_0-rmse:25.82432	validation_1-rmse:28.50378
# [176]	validation_0-rmse:25.76945	validation_1-rmse:28.50196
# [177]	validation_0-rmse:25.71665	validation_1-rmse:28.48900
# [178]	validation_0-rmse:25.66039	validation_1-rmse:28.50839
# [179]	validation_0-rmse:25.59970	validation_1-rmse:28.51989
# [180]	validation_0-rmse:25.56689	validation_1-rmse:28.53160
# [181]	validation_0-rmse:25.52725	validation_1-rmse:28.52891
# [182]	validation_0-rmse:25.49225	validation_1-rmse:28.51976
# [183]	validation_0-rmse:25.37424	validation_1-rmse:28.53452
# [184]	validation_0-rmse:25.30001	validation_1-rmse:28.52096
# [185]	validation_0-rmse:25.24048	validation_1-rmse:28.52857
# [186]	validation_0-rmse:25.17681	validation_1-rmse:28.52652
# [187]	validation_0-rmse:25.12847	validation_1-rmse:28.47415
# [188]	validation_0-rmse:25.10624	validation_1-rmse:28.48468
# [189]	validation_0-rmse:25.06619	validation_1-rmse:28.48192
# [190]	validation_0-rmse:25.01954	validation_1-rmse:28.46699
# [191]	validation_0-rmse:24.96862	validation_1-rmse:28.47056
# [192]	validation_0-rmse:24.90603	validation_1-rmse:28.47510
# [193]	validation_0-rmse:24.85376	validation_1-rmse:28.47699
# [194]	validation_0-rmse:24.78194	validation_1-rmse:28.48724
# [195]	validation_0-rmse:24.71183	validation_1-rmse:28.49388
# [196]	validation_0-rmse:24.66975	validation_1-rmse:28.50855
# [197]	validation_0-rmse:24.63377	validation_1-rmse:28.52600
# [198]	validation_0-rmse:24.60185	validation_1-rmse:28.53762
# [199]	validation_0-rmse:24.53573	validation_1-rmse:28.55002
# [200]	validation_0-rmse:24.46123	validation_1-rmse:28.55757
# [201]	validation_0-rmse:24.43724	validation_1-rmse:28.54763
# [202]	validation_0-rmse:24.39608	validation_1-rmse:28.55876
# [203]	validation_0-rmse:24.33617	validation_1-rmse:28.56870
# [204]	validation_0-rmse:24.29234	validation_1-rmse:28.56459
# [205]	validation_0-rmse:24.20808	validation_1-rmse:28.56345
# [206]	validation_0-rmse:24.16877	validation_1-rmse:28.57057
# [207]	validation_0-rmse:24.12461	validation_1-rmse:28.56913
# [208]	validation_0-rmse:24.08107	validation_1-rmse:28.56312
# [209]	validation_0-rmse:24.00401	validation_1-rmse:28.54803
# [210]	validation_0-rmse:23.93350	validation_1-rmse:28.57170
# [211]	validation_0-rmse:23.88693	validation_1-rmse:28.56205
# [212]	validation_0-rmse:23.81455	validation_1-rmse:28.54116
# [213]	validation_0-rmse:23.79721	validation_1-rmse:28.57208
# [214]	validation_0-rmse:23.76003	validation_1-rmse:28.57506
# [215]	validation_0-rmse:23.72386	validation_1-rmse:28.57195
# [216]	validation_0-rmse:23.69113	validation_1-rmse:28.56677
# [217]	validation_0-rmse:23.64941	validation_1-rmse:28.55364
# [218]	validation_0-rmse:23.58237	validation_1-rmse:28.55258
# [219]	validation_0-rmse:23.56241	validation_1-rmse:28.53381
# [220]	validation_0-rmse:23.49812	validation_1-rmse:28.58226
# [221]	validation_0-rmse:23.47721	validation_1-rmse:28.58135
# [222]	validation_0-rmse:23.43638	validation_1-rmse:28.57936
# [223]	validation_0-rmse:23.36673	validation_1-rmse:28.60563
# [224]	validation_0-rmse:23.33294	validation_1-rmse:28.60791
# [225]	validation_0-rmse:23.28258	validation_1-rmse:28.58570
# [226]	validation_0-rmse:23.24486	validation_1-rmse:28.57916
# [227]	validation_0-rmse:23.20136	validation_1-rmse:28.56324
# [228]	validation_0-rmse:23.15959	validation_1-rmse:28.56408
# [229]	validation_0-rmse:23.11418	validation_1-rmse:28.53526
# [230]	validation_0-rmse:23.03495	validation_1-rmse:28.52645
# [231]	validation_0-rmse:22.98368	validation_1-rmse:28.52906
# [232]	validation_0-rmse:22.91615	validation_1-rmse:28.54092
# [233]	validation_0-rmse:22.87266	validation_1-rmse:28.53960
# [234]	validation_0-rmse:22.84686	validation_1-rmse:28.49509
# [235]	validation_0-rmse:22.79095	validation_1-rmse:28.50149
# [236]	validation_0-rmse:22.74017	validation_1-rmse:28.47567
# [237]	validation_0-rmse:22.67319	validation_1-rmse:28.43966
# [238]	validation_0-rmse:22.64602	validation_1-rmse:28.43352
# [239]	validation_0-rmse:22.60740	validation_1-rmse:28.43199
# [240]	validation_0-rmse:22.56660	validation_1-rmse:28.43884
# [241]	validation_0-rmse:22.54437	validation_1-rmse:28.44452
# [242]	validation_0-rmse:22.52238	validation_1-rmse:28.45918
# [243]	validation_0-rmse:22.47021	validation_1-rmse:28.46601
# [244]	validation_0-rmse:22.41849	validation_1-rmse:28.46588
# [245]	validation_0-rmse:22.38199	validation_1-rmse:28.47316
# [246]	validation_0-rmse:22.34872	validation_1-rmse:28.47264
# [247]	validation_0-rmse:22.30914	validation_1-rmse:28.50004
# [248]	validation_0-rmse:22.25054	validation_1-rmse:28.50236
# [249]	validation_0-rmse:22.22545	validation_1-rmse:28.50111
# [250]	validation_0-rmse:22.20000	validation_1-rmse:28.49465
# [251]	validation_0-rmse:22.15900	validation_1-rmse:28.49900
# [252]	validation_0-rmse:22.12924	validation_1-rmse:28.49911
# [253]	validation_0-rmse:22.09300	validation_1-rmse:28.48939
# [254]	validation_0-rmse:22.05386	validation_1-rmse:28.48619
# [255]	validation_0-rmse:22.00449	validation_1-rmse:28.48409
# [256]	validation_0-rmse:21.98870	validation_1-rmse:28.49673
# [257]	validation_0-rmse:21.94936	validation_1-rmse:28.49554
# [258]	validation_0-rmse:21.94007	validation_1-rmse:28.49749
# [259]	validation_0-rmse:21.88794	validation_1-rmse:28.46048
# [260]	validation_0-rmse:21.87439	validation_1-rmse:28.44492
# [261]	validation_0-rmse:21.84780	validation_1-rmse:28.45317
# [262]	validation_0-rmse:21.81341	validation_1-rmse:28.45581
# [263]	validation_0-rmse:21.76633	validation_1-rmse:28.47147
# [264]	validation_0-rmse:21.73852	validation_1-rmse:28.45686
# [265]	validation_0-rmse:21.70731	validation_1-rmse:28.46407
# [266]	validation_0-rmse:21.65911	validation_1-rmse:28.46865
# [267]	validation_0-rmse:21.62625	validation_1-rmse:28.46744
# [268]	validation_0-rmse:21.59949	validation_1-rmse:28.45470
# [269]	validation_0-rmse:21.52883	validation_1-rmse:28.43832
# [270]	validation_0-rmse:21.49556	validation_1-rmse:28.43629
# [271]	validation_0-rmse:21.46140	validation_1-rmse:28.41606
# [272]	validation_0-rmse:21.42662	validation_1-rmse:28.41097
# [273]	validation_0-rmse:21.37409	validation_1-rmse:28.41188
# [274]	validation_0-rmse:21.33265	validation_1-rmse:28.42104
# [275]	validation_0-rmse:21.27985	validation_1-rmse:28.42463
# [276]	validation_0-rmse:21.25766	validation_1-rmse:28.43192
# [277]	validation_0-rmse:21.22908	validation_1-rmse:28.40666
# [278]	validation_0-rmse:21.19892	validation_1-rmse:28.40672
# [279]	validation_0-rmse:21.14864	validation_1-rmse:28.41979
# [280]	validation_0-rmse:21.12484	validation_1-rmse:28.42490
# [281]	validation_0-rmse:21.08301	validation_1-rmse:28.40908
# [282]	validation_0-rmse:21.03203	validation_1-rmse:28.42455
# [283]	validation_0-rmse:21.01854	validation_1-rmse:28.42219
# [284]	validation_0-rmse:20.96419	validation_1-rmse:28.42636
# [285]	validation_0-rmse:20.93980	validation_1-rmse:28.42569
# [286]	validation_0-rmse:20.91306	validation_1-rmse:28.41551
# [287]	validation_0-rmse:20.89495	validation_1-rmse:28.40877
# [288]	validation_0-rmse:20.86154	validation_1-rmse:28.40420
# [289]	validation_0-rmse:20.82304	validation_1-rmse:28.40866
# [290]	validation_0-rmse:20.80268	validation_1-rmse:28.40571
# [291]	validation_0-rmse:20.75325	validation_1-rmse:28.40966
# [292]	validation_0-rmse:20.72434	validation_1-rmse:28.40644
# [293]	validation_0-rmse:20.69590	validation_1-rmse:28.41145
# [294]	validation_0-rmse:20.64813	validation_1-rmse:28.38694
# [295]	validation_0-rmse:20.62216	validation_1-rmse:28.39598
# [296]	validation_0-rmse:20.59591	validation_1-rmse:28.36882
# [297]	validation_0-rmse:20.55697	validation_1-rmse:28.42487
# [298]	validation_0-rmse:20.48940	validation_1-rmse:28.41756
# [299]	validation_0-rmse:20.47211	validation_1-rmse:28.42029
# [300]	validation_0-rmse:20.42373	validation_1-rmse:28.42444
# [301]	validation_0-rmse:20.39320	validation_1-rmse:28.41689
# [302]	validation_0-rmse:20.36351	validation_1-rmse:28.41397
# [303]	validation_0-rmse:20.33069	validation_1-rmse:28.43584
# [304]	validation_0-rmse:20.30114	validation_1-rmse:28.44846
# [305]	validation_0-rmse:20.27553	validation_1-rmse:28.44200
# [306]	validation_0-rmse:20.21800	validation_1-rmse:28.43563
# [307]	validation_0-rmse:20.19698	validation_1-rmse:28.43762
# [308]	validation_0-rmse:20.15854	validation_1-rmse:28.42893
# [309]	validation_0-rmse:20.13715	validation_1-rmse:28.43573
# [310]	validation_0-rmse:20.08861	validation_1-rmse:28.43861
# [311]	validation_0-rmse:20.06381	validation_1-rmse:28.43922
# [312]	validation_0-rmse:20.04223	validation_1-rmse:28.43114
# [313]	validation_0-rmse:20.00689	validation_1-rmse:28.43312
# [314]	validation_0-rmse:19.97792	validation_1-rmse:28.42525
# [315]	validation_0-rmse:19.95190	validation_1-rmse:28.42488
# [316]	validation_0-rmse:19.90418	validation_1-rmse:28.43986
# [317]	validation_0-rmse:19.89146	validation_1-rmse:28.41671
# [318]	validation_0-rmse:19.86162	validation_1-rmse:28.43493
# [319]	validation_0-rmse:19.83534	validation_1-rmse:28.43162
# [320]	validation_0-rmse:19.80947	validation_1-rmse:28.43094
# [321]	validation_0-rmse:19.77869	validation_1-rmse:28.42616
# [322]	validation_0-rmse:19.74346	validation_1-rmse:28.42755
# [323]	validation_0-rmse:19.68628	validation_1-rmse:28.40271
# [324]	validation_0-rmse:19.63733	validation_1-rmse:28.40149
# [325]	validation_0-rmse:19.60422	validation_1-rmse:28.39980
# [326]	validation_0-rmse:19.58007	validation_1-rmse:28.41734
# [327]	validation_0-rmse:19.55038	validation_1-rmse:28.41017
# [328]	validation_0-rmse:19.51384	validation_1-rmse:28.43568
# [329]	validation_0-rmse:19.49869	validation_1-rmse:28.43620
# [330]	validation_0-rmse:19.47998	validation_1-rmse:28.44923
# [331]	validation_0-rmse:19.45206	validation_1-rmse:28.44672
# [332]	validation_0-rmse:19.40475	validation_1-rmse:28.44859
# [333]	validation_0-rmse:19.36648	validation_1-rmse:28.44398
# [334]	validation_0-rmse:19.34242	validation_1-rmse:28.44579
# [335]	validation_0-rmse:19.31396	validation_1-rmse:28.44028
# [336]	validation_0-rmse:19.29101	validation_1-rmse:28.44288
# [337]	validation_0-rmse:19.26285	validation_1-rmse:28.42980
# [338]	validation_0-rmse:19.22801	validation_1-rmse:28.43016
# [339]	validation_0-rmse:19.19292	validation_1-rmse:28.44391
# [340]	validation_0-rmse:19.16805	validation_1-rmse:28.44198
# [341]	validation_0-rmse:19.13908	validation_1-rmse:28.42342
# [342]	validation_0-rmse:19.09288	validation_1-rmse:28.42355
# [343]	validation_0-rmse:19.04028	validation_1-rmse:28.42608
# [344]	validation_0-rmse:18.98440	validation_1-rmse:28.44128
# [345]	validation_0-rmse:18.96602	validation_1-rmse:28.45378
# [346]	validation_0-rmse:18.94758	validation_1-rmse:28.45914
# 2025-12-17 20:45:11 - train_model - INFO - Best iteration: 296
# 2025-12-17 20:45:11 - train_model - INFO - Best score: 28.368818859300504

# %% [markdown]
# ## 5. Evaluate Model

# %%
# Evaluate on all sets
train_metrics = evaluate_model(model, X_train_scaled, y_train, set_name="Train")
val_metrics = evaluate_model(model, X_val_scaled, y_val, set_name="Validation")
test_metrics = evaluate_model(model, X_test_scaled, y_test, set_name="Test")
# Out:
# 2025-12-17 20:45:11 - train_model - INFO - Train Set Performance:
# 2025-12-17 20:45:11 - train_model - INFO -   MAE:  15.26 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   RMSE: 20.60 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   MAPE: inf%
# 2025-12-17 20:45:11 - train_model - INFO -   R²:   0.9721
# 2025-12-17 20:45:11 - train_model - INFO - Validation Set Performance:
# 2025-12-17 20:45:11 - train_model - INFO -   MAE:  20.70 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   RMSE: 28.37 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   MAPE: inf%
# 2025-12-17 20:45:11 - train_model - INFO -   R²:   0.4043
# 2025-12-17 20:45:11 - train_model - INFO - Test Set Performance:
# 2025-12-17 20:45:11 - train_model - INFO -   MAE:  27.05 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   RMSE: 41.30 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   MAPE: inf%
# 2025-12-17 20:45:11 - train_model - INFO -   R²:   0.4839

# %% [markdown]
# ## 6. Baseline Models (Naive Forecasters)
#
# Let's compare the XGBoost model against simple baseline models to understand the value added by machine learning.

# %%
# Train 24-hour persistence baseline (predict tomorrow's price = today's price)
baseline_24h = NaivePersistence(strategy='24h')
baseline_24h.fit(X_train, y_train)

# Train 168-hour persistence baseline (predict next week's price = last week's price)
baseline_168h = NaivePersistence(strategy='168h')
baseline_168h.fit(X_train, y_train)

print("Baseline models initialized successfully!")
print(f"  - 24h Persistence: Uses price_lag_0 (current price)")
print(f"  - 168h Persistence: Uses price_lag_144 (price from 6 days ago)")
# Out:
# Baseline models initialized successfully!
#   - 24h Persistence: Uses price_lag_0 (current price)
#   - 168h Persistence: Uses price_lag_144 (price from 6 days ago)

# %%
# Evaluate baseline models on test set
print("Evaluating Baseline Models on Test Set:")
print("="*60)

baseline_24h_metrics = evaluate_model(baseline_24h, X_test, y_test, set_name="Baseline 24h")
print()
baseline_168h_metrics = evaluate_model(baseline_168h, X_test, y_test, set_name="Baseline 168h")
print()
print("XGBoost Model (for comparison):")
print(f"  MAE:  {test_metrics['MAE']:.2f} €/MWh")
print(f"  RMSE: {test_metrics['RMSE']:.2f} €/MWh")
print(f"  R²:   {test_metrics['R2']:.4f}")
# Out:
# Evaluating Baseline Models on Test Set:
# ============================================================
# 2025-12-17 20:45:11 - train_model - INFO - Baseline 24h Set Performance:
# 2025-12-17 20:45:11 - train_model - INFO -   MAE:  29.82 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   RMSE: 47.21 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   MAPE: inf%
# 2025-12-17 20:45:11 - train_model - INFO -   R²:   0.3256
#
# 2025-12-17 20:45:11 - train_model - INFO - Baseline 168h Set Performance:
# 2025-12-17 20:45:11 - train_model - INFO -   MAE:  35.55 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   RMSE: 59.39 €/MWh
# 2025-12-17 20:45:11 - train_model - INFO -   MAPE: inf%
# 2025-12-17 20:45:11 - train_model - INFO -   R²:   -0.0675
#
# XGBoost Model (for comparison):
#   MAE:  27.05 €/MWh
#   RMSE: 41.30 €/MWh
#   R²:   0.4839

# %%
# Get predictions from all models
y_pred_24h = baseline_24h.predict(X_test)
y_pred_168h = baseline_168h.predict(X_test)
y_pred_xgb = model.predict(X_test_scaled)

# Compare all models
comparison_df = pd.DataFrame({
    'Baseline 24h': baseline_24h_metrics,
    'Baseline 168h': baseline_168h_metrics,
    'XGBoost': test_metrics
})

print("\nModel Comparison (Test Set):")
print(comparison_df.round(2))
# Out:
# Model Comparison (Test Set):
#       Baseline 24h  Baseline 168h  XGBoost
# MAE          29.82          35.55    27.05
# RMSE         47.21          59.39    41.30
# MAPE           inf            inf      inf
# R2            0.33          -0.07     0.48

# %%
# Visualize model comparison
fig = go.Figure()

metrics = ['MAE', 'RMSE', 'R2']
models = ['Baseline 24h', 'Baseline 168h', 'XGBoost']

for metric in metrics:
    if metric == 'R2':
        # R² on secondary y-axis
        continue
    fig.add_trace(go.Bar(
        name=metric,
        x=models,
        y=[comparison_df.loc[metric, model] for model in models],
    ))

fig.update_layout(
    title='Model Performance Comparison (Test Set)',
    xaxis_title='Model',
    yaxis_title='Error (€/MWh)',
    barmode='group',
    height=500,
    showlegend=True
)

fig.show()

# %%
# Compare predictions visually on a subset of test data (first 7 days)
n_hours = 7 * 24  # 7 days
plot_start = 0
plot_end = min(n_hours, len(y_test))

fig = go.Figure()

# Actual prices
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_test.values[plot_start:plot_end],
    name='Actual',
    line=dict(color='black', width=2),
    mode='lines'
))

# XGBoost predictions
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_pred_xgb[plot_start:plot_end],
    name='XGBoost',
    line=dict(color='green', width=1.5),
    mode='lines'
))

# 24h baseline
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_pred_24h[plot_start:plot_end],
    name='Baseline 24h',
    line=dict(color='blue', width=1.5, dash='dash'),
    mode='lines'
))

# 168h baseline
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_pred_168h[plot_start:plot_end],
    name='Baseline 168h',
    line=dict(color='red', width=1.5, dash='dot'),
    mode='lines'
))

fig.update_layout(
    title='Model Predictions Comparison (First Week of Test Set)',
    xaxis_title='Date',
    yaxis_title='Price (€/MWh)',
    height=500,
    hovermode='x unified',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

# %%
# Calculate improvement over baselines
mae_improvement_24h = ((baseline_24h_metrics['MAE'] - test_metrics['MAE']) / baseline_24h_metrics['MAE']) * 100
mae_improvement_168h = ((baseline_168h_metrics['MAE'] - test_metrics['MAE']) / baseline_168h_metrics['MAE']) * 100

rmse_improvement_24h = ((baseline_24h_metrics['RMSE'] - test_metrics['RMSE']) / baseline_24h_metrics['RMSE']) * 100
rmse_improvement_168h = ((baseline_168h_metrics['RMSE'] - test_metrics['RMSE']) / baseline_168h_metrics['RMSE']) * 100

print("\n" + "="*60)
print("XGBoost IMPROVEMENT OVER BASELINES")
print("="*60)
print(f"\nVs. 24h Persistence:")
print(f"  MAE improvement:  {mae_improvement_24h:.1f}%")
print(f"  RMSE improvement: {rmse_improvement_24h:.1f}%")

print(f"\nVs. 168h Persistence:")
print(f"  MAE improvement:  {mae_improvement_168h:.1f}%")
print(f"  RMSE improvement: {rmse_improvement_168h:.1f}%")

print(f"\nAbsolute Performance:")
print(f"  XGBoost MAE:      {test_metrics['MAE']:.2f} €/MWh")
print(f"  24h Baseline MAE: {baseline_24h_metrics['MAE']:.2f} €/MWh")
print(f"  168h Baseline MAE: {baseline_168h_metrics['MAE']:.2f} €/MWh")
# Out:
# ============================================================
# XGBoost IMPROVEMENT OVER BASELINES
# ============================================================
#
# Vs. 24h Persistence:
#   MAE improvement:  9.3%
#   RMSE improvement: 12.5%
#
# Vs. 168h Persistence:
#   MAE improvement:  23.9%
#   RMSE improvement: 30.5%
#
# Absolute Performance:
#   XGBoost MAE:      27.05 €/MWh
#   24h Baseline MAE: 29.82 €/MWh
#   168h Baseline MAE: 35.55 €/MWh

# %% [markdown]
# ## 6.5. ARIMA Statistical Model
#
# Let's also train an ARIMA/SARIMAX model to see how statistical time series methods compare.

# %%
# Import ARIMA model
from models.statistical import ArimaEstimator
from models.train import train_statistical_model

# Select basic exogenous features (avoid overfitting with too many features)
basic_features = ['load_forecast', 'wind_onshore', 'wind_offshore', 'solar',
                 'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos']
exog_cols = [c for c in basic_features if c in X_train.columns]

print(f"Using {len(exog_cols)} exogenous features for ARIMA:")
print(exog_cols)
# Out:
# Using 8 exogenous features for ARIMA:
# ['load_forecast', 'wind_onshore', 'wind_offshore', 'solar', 'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos']

# %%
# Train ARIMA model with manual order (1,1,1)
# Note: This will take 1-2 minutes
print("Training ARIMA(1,1,1) model with exogenous variables...")

arima_model = ArimaEstimator(
    order=(1, 1, 1),
    seasonal_order=(0, 0, 0, 0),
    use_auto_arima=False,
    exog_cols=exog_cols,
    scale_exog=True
)

# Fit on training data
arima_model.fit(X_train, y_train)

print("ARIMA model training complete!")
# Out:
# Training ARIMA(1,1,1) model with exogenous variables...
# ARIMA model training complete!

# %%
# Evaluate ARIMA model on test set
arima_metrics = evaluate_model(arima_model, X_test, y_test, set_name="ARIMA")

# Get predictions for visualization
y_pred_arima = arima_model.predict(X_test)

# Update comparison
comparison_df['ARIMA'] = arima_metrics

print("\nUpdated Model Comparison (Test Set):")
print(comparison_df[['Baseline 24h', 'Baseline 168h', 'XGBoost', 'ARIMA']].round(2))
# Out:
# 2025-12-17 20:45:17 - train_model - INFO - ARIMA Set Performance:
# 2025-12-17 20:45:17 - train_model - INFO -   MAE:  44.14 €/MWh
# 2025-12-17 20:45:17 - train_model - INFO -   RMSE: 57.34 €/MWh
# 2025-12-17 20:45:17 - train_model - INFO -   MAPE: inf%
# 2025-12-17 20:45:17 - train_model - INFO -   R²:   0.0052
#
# Updated Model Comparison (Test Set):
#       Baseline 24h  Baseline 168h  XGBoost  ARIMA
# MAE          29.82          35.55    27.05  44.14
# RMSE         47.21          59.39    41.30  57.34
# MAPE           inf            inf      inf    inf
# R2            0.33          -0.07     0.48   0.01

# %%
# Visualize ARIMA predictions alongside other models
n_hours = 7 * 24  # 7 days
plot_start = 0
plot_end = min(n_hours, len(y_test))

fig = go.Figure()

# Actual prices
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_test.values[plot_start:plot_end],
    name='Actual',
    line=dict(color='black', width=2),
    mode='lines'
))

# XGBoost predictions
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_pred_xgb[plot_start:plot_end],
    name='XGBoost',
    line=dict(color='green', width=1.5),
    mode='lines'
))

# ARIMA predictions
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_pred_arima[plot_start:plot_end],
    name='ARIMA',
    line=dict(color='purple', width=1.5),
    mode='lines'
))

# 24h baseline
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_pred_24h[plot_start:plot_end],
    name='Baseline 24h',
    line=dict(color='blue', width=1.5, dash='dash'),
    mode='lines'
))

# 168h baseline
fig.add_trace(go.Scatter(
    x=y_test.index[plot_start:plot_end],
    y=y_pred_168h[plot_start:plot_end],
    name='Baseline 168h',
    line=dict(color='red', width=1.5, dash='dot'),
    mode='lines'
))

fig.update_layout(
    title='All Models Comparison (First Week of Test Set)',
    xaxis_title='Date',
    yaxis_title='Price (€/MWh)',
    height=500,
    hovermode='x unified',
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

# %%
# Performance comparison bar chart with ARIMA
fig = go.Figure()

models_list = ['Baseline 24h', 'Baseline 168h', 'ARIMA', 'XGBoost']
metrics_to_plot = ['MAE', 'RMSE']

for metric in metrics_to_plot:
    fig.add_trace(go.Bar(
        name=metric,
        x=models_list,
        y=[comparison_df.loc[metric, model] for model in models_list],
    ))

fig.update_layout(
    title='Model Performance Comparison (Test Set) - All Models',
    xaxis_title='Model',
    yaxis_title='Error (€/MWh)',
    barmode='group',
    height=500,
    showlegend=True
)

fig.show()

# %%
# Plot predictions vs actual
y_test_pred = model.predict(X_test_scaled)

# Create subplots
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=('Test Set: Actual vs Predicted Prices', 'Predicted vs Actual Scatter Plot'),
    vertical_spacing=0.12
)

# Time series plot
fig.add_trace(
    go.Scatter(x=y_test.index, y=y_test.values, name='Actual', 
               line=dict(color='blue', width=1.5), opacity=0.7),
    row=1, col=1
)
fig.add_trace(
    go.Scatter(x=y_test.index, y=y_test_pred, name='Predicted', 
               line=dict(color='red', width=1.5), opacity=0.7),
    row=1, col=1
)

# Scatter plot
fig.add_trace(
    go.Scatter(x=y_test.values, y=y_test_pred, mode='markers',
               marker=dict(color='blue', size=4, opacity=0.5),
               name='Predictions', showlegend=False),
    row=2, col=1
)

# Add perfect prediction line
min_val, max_val = y_test.min(), y_test.max()
fig.add_trace(
    go.Scatter(x=[min_val, max_val], y=[min_val, max_val],
               mode='lines', line=dict(color='red', dash='dash', width=2),
               name='Perfect Prediction', showlegend=False),
    row=2, col=1
)

# Update axes
fig.update_xaxes(title_text="Date", row=1, col=1)
fig.update_yaxes(title_text="Price (€/MWh)", row=1, col=1)
fig.update_xaxes(title_text="Actual Price (€/MWh)", row=2, col=1)
fig.update_yaxes(title_text="Predicted Price (€/MWh)", row=2, col=1)

fig.update_layout(height=800, showlegend=True)
fig.show()

# %%
# Error distribution and residual plot
errors = y_test.values - y_test_pred

fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Error Distribution', 'Residual Plot'),
    horizontal_spacing=0.12
)

# Histogram of errors
fig.add_trace(
    go.Histogram(x=errors, nbinsx=50, name='Errors',
                 marker=dict(color='steelblue', line=dict(color='black', width=1))),
    row=1, col=1
)

# Add vertical line at 0
fig.add_vline(x=0, line_dash="dash", line_color="red", line_width=2, row=1, col=1)

# Residual scatter plot
fig.add_trace(
    go.Scatter(x=y_test_pred, y=errors, mode='markers',
               marker=dict(color='steelblue', size=4, opacity=0.5),
               name='Residuals', showlegend=False),
    row=1, col=2
)

# Add horizontal line at 0
fig.add_hline(y=0, line_dash="dash", line_color="red", line_width=2, row=1, col=2)

# Update axes
fig.update_xaxes(title_text="Prediction Error (€/MWh)", row=1, col=1)
fig.update_yaxes(title_text="Frequency", row=1, col=1)
fig.update_xaxes(title_text="Predicted Price (€/MWh)", row=1, col=2)
fig.update_yaxes(title_text="Prediction Error (€/MWh)", row=1, col=2)

fig.update_layout(height=400, showlegend=False)
fig.show()

# %% [markdown]
# ## 7. Feature Importance

# %%
# Get top features
feature_importance = get_feature_importance(
    model,
    X_train.columns.tolist(),
    top_n=20
)

print("Top 20 Most Important Features:")
print(feature_importance)
# Out:
# Top 20 Most Important Features:
#                    feature  importance
# 24             price_lag_0    0.317366
# 25             price_lag_1    0.295739
# 26             price_lag_2    0.094244
# 41    price_rolling_12_max    0.030291
# 32           price_lag_144    0.021378
# 37     price_rolling_6_max    0.020968
# 8          day_of_week_cos    0.014651
# 31            price_lag_48    0.013952
# 30            price_lag_24    0.012896
# 46  price_rolling_168_mean    0.011167
# 23    load_forecast_future    0.008545
# 10               month_cos    0.008380
# 45    price_rolling_24_max    0.005527
# 0            load_forecast    0.004888
# 38   price_rolling_12_mean    0.004700
# 7          day_of_week_sin    0.004418
# 48   price_rolling_168_min    0.004268
# 42   price_rolling_24_mean    0.004257
# 50     load_forecast_lag_1    0.004015
# 6                 hour_cos    0.004007

# %%
# Plot feature importance
fig = go.Figure()

fig.add_trace(go.Bar(
    x=feature_importance['importance'].values,
    y=feature_importance['feature'].values,
    orientation='h',
    marker=dict(color='steelblue')
))

fig.update_layout(
    title='Top 20 Feature Importance',
    xaxis_title='Importance',
    yaxis_title='Feature',
    height=600,
    yaxis=dict(autorange='reversed')  # Highest importance at top
)

fig.show()

# %% [markdown]
# ## 8. Save Model

# %%
# Save trained model and feature engine
save_model(
    model,
    feature_engine,
    save_dir="../models",
    model_name="xgboost_24h_forecast"
)
# Out:
# 2025-12-17 20:45:17 - train_model - INFO - Model saved to: ../models/xgboost_24h_forecast.json
# 2025-12-17 20:45:17 - train_model - INFO - Feature engine saved to: ../models/xgboost_24h_forecast_feature_engine.pkl
# 2025-12-17 20:45:17 - train_model - INFO - Feature names saved to: ../models/xgboost_24h_forecast_features.json

# %% [markdown]
# ## 9. Model Insights

# %%
# Analyze errors by hour of day
error_by_hour = pd.DataFrame({
    'hour': y_test.index.hour,
    'error': np.abs(errors)
}).groupby('hour')['error'].mean()

fig = go.Figure()

fig.add_trace(go.Bar(
    x=error_by_hour.index,
    y=error_by_hour.values,
    marker=dict(color='steelblue')
))

fig.update_layout(
    title='Forecast Error by Hour of Day',
    xaxis_title='Hour of Day',
    yaxis_title='Mean Absolute Error (€/MWh)',
    height=400,
    showlegend=False
)

fig.show()

# %%
# Metrics comparison across train/val/test sets
metrics_df = pd.DataFrame({
    'Train': train_metrics,
    'Validation': val_metrics,
    'Test': test_metrics
})

# Plot metrics comparison
fig = go.Figure()

for metric in ['MAE', 'RMSE']:
    fig.add_trace(go.Bar(
        name=metric,
        x=['Train', 'Validation', 'Test'],
        y=metrics_df.loc[metric],
    ))

fig.update_layout(
    title='Model Performance Across Sets',
    xaxis_title='Dataset',
    yaxis_title='Error (€/MWh)',
    barmode='group',
    height=400
)

fig.show()
