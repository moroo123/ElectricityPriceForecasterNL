# %% [markdown]
# # Model Training: XGBoost Price Forecasting
#
# This notebook demonstrates how to use the feature pipeline to train an XGBoost model for electricity price forecasting.

# %%
import pandas as pd
import numpy as np
import sys
from pathlib import Path

# Add src to path
sys.path.append('../src')

from utils.preprocessing import (
    create_merged_dataset,
    split_train_val_test,
    handle_missing_values
)
from features.pipeline import TimeSeriesFeatureEngine
from models.train import (
    train_xgboost_model,
    evaluate_model,
    get_feature_importance,
    save_model
)

# Plotly for interactive visualizations
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# %% [markdown]
# ## 1. Load and Prepare Data

# %%
# Load merged dataset from cache
df = create_merged_dataset(db_path="../data/cache.db")

print(f"Dataset shape: {df.shape}")
print(f"Date range: {df.index.min()} to {df.index.max()}")
print(f"\nColumns: {df.columns.tolist()}")

df.head()
# Out:
# Dataset shape: (26305, 6)
# Date range: 2022-01-01 00:00:00+01:00 to 2025-01-01 00:00:00+01:00
#
# Columns: ['price', 'load_forecast', 'actual_load', 'wind_onshore', 'wind_offshore', 'solar']
#                             price  load_forecast  actual_load  wind_onshore  \
# timestamp
# 2022-01-01 00:00:00+01:00  124.70     11532.1925   10374.1425       2646.25
# 2022-01-01 01:00:00+01:00  124.70     11085.1050   10249.9175       2419.75
# 2022-01-01 02:00:00+01:00  134.00     10805.7575    9907.0350       2161.75
# 2022-01-01 03:00:00+01:00   58.80     10676.2475    9782.3050       1954.75
# 2022-01-01 04:00:00+01:00   37.67     10643.9175    9589.5250       1706.75
#
#                            wind_offshore  solar
# timestamp
# 2022-01-01 00:00:00+01:00        1352.75    0.0
# 2022-01-01 01:00:00+01:00        1307.50    0.0
# 2022-01-01 02:00:00+01:00        1234.75    0.0
# 2022-01-01 03:00:00+01:00        1129.25    0.0
# 2022-01-01 04:00:00+01:00        1044.00    0.0

# %%
# Check for missing values
missing = df.isnull().sum()
print("Missing values per column:")
print(missing[missing > 0])
# Out:
# Missing values per column:
# load_forecast     1
# actual_load       1
# wind_onshore     25
# wind_offshore    25
# solar            25
# dtype: int64

# %%
# Handle missing values (forward fill with limit)
df_clean = handle_missing_values(df, strategy='forward_fill', limit=24)

# Drop any remaining NaN rows
df_clean = df_clean.dropna()

print(f"Clean dataset shape: {df_clean.shape}")
# Out:
# Clean dataset shape: (26305, 6)

# %% [markdown]
# ## 2. Split Data (Time-based)

# %%
# Time-based split (no shuffling!)
train_df, val_df, test_df = split_train_val_test(
    df_clean,
    train_end="2023-12-31",
    val_end="2024-06-30"
)
# Out:
# Train: 2022-01-01 00:00:00+01:00 to 2023-12-31 00:00:00+01:00 (17497 samples)
# Val:   2023-12-31 01:00:00+01:00 to 2024-06-30 00:00:00+02:00 (4367 samples)
# Test:  2024-06-30 01:00:00+02:00 to 2025-01-01 00:00:00+01:00 (4441 samples)

# %% [markdown]
# ## 3. Create Features

# %%
# Initialize feature engine
feature_engine = TimeSeriesFeatureEngine(
    target_col='price',
    forecast_horizon=24,
    feature_config={'scaler_type': 'robust'},
    price_lags=[1, 2, 3, 6, 12, 24, 48, 168],  # Recent hours + same-hour lags
    price_windows=[6, 12, 24, 168],             # Short-term + long-term windows
    load_lags=[1, 24, 168]                      # Recent + seasonal
)

print("Feature engine initialized")
# Out:
# Feature engine initialized

# %%
# Create features for train, val, test sets
print("Creating training features...")
X_train, y_train = feature_engine.prepare_data(train_df, create_target=True)

print("Creating validation features...")
X_val, y_val = feature_engine.prepare_data(val_df, create_target=True)

print("Creating test features...")
X_test, y_test = feature_engine.prepare_data(test_df, create_target=True)

print(f"\nTrain: X={X_train.shape}, y={y_train.shape}")
print(f"Val:   X={X_val.shape}, y={y_val.shape}")
print(f"Test:  X={X_test.shape}, y={y_test.shape}")
# Out:
# Creating training features...
# Creating validation features...
# Creating test features...
#
# Train: X=(17473, 65), y=(17473,)
# Val:   X=(4343, 65), y=(4343,)
# Test:  X=(4417, 65), y=(4417,)

# %%
# Fill any remaining NaN values with 0
X_train = X_train.fillna(0)
X_val = X_val.fillna(0)
X_test = X_test.fillna(0)

print(f"Total features created: {X_train.shape[1]}")
print(f"\nFeature names (first 20):")
print(X_train.columns.tolist()[:20])
# Out:
# Total features created: 65
#
# Feature names (first 20):
# ['load_forecast', 'actual_load', 'wind_onshore', 'wind_offshore', 'solar', 'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos', 'month_sin', 'month_cos', 'is_weekend', 'total_renewable', 'total_wind', 'residual_load', 'residual_load_pct', 'renewable_penetration', 'wind_onshore_ratio', 'wind_offshore_ratio', 'solar_ratio']

# %% [markdown]
# ## 4. Train XGBoost Model

# %%
# Fit scaler on training data
feature_engine.fit(X_train, y_train)

# Transform features
X_train_scaled = feature_engine.transform(X_train)
X_val_scaled = feature_engine.transform(X_val)
X_test_scaled = feature_engine.transform(X_test)

# %%
# Train model with early stopping
model = train_xgboost_model(
    X_train_scaled,
    y_train,
    X_val_scaled,
    y_val,
    params={
        'learning_rate': 0.05,
        'max_depth': 6,
        'min_child_weight': 3,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
    },
    n_estimators=1000,
    early_stopping_rounds=50,
    verbose=True
)
# Out:
# [0]	validation_0-rmse:118.31753	validation_1-rmse:104.82109
# [1]	validation_0-rmse:113.61268	validation_1-rmse:100.69558
# [2]	validation_0-rmse:109.25523	validation_1-rmse:97.60646
# [3]	validation_0-rmse:105.07267	validation_1-rmse:93.80094
# [4]	validation_0-rmse:101.13739	validation_1-rmse:90.24394
# [5]	validation_0-rmse:97.40336	validation_1-rmse:86.91937
# [6]	validation_0-rmse:93.91515	validation_1-rmse:83.57511
# [7]	validation_0-rmse:90.57611	validation_1-rmse:80.88942
# [8]	validation_0-rmse:87.42139	validation_1-rmse:78.14343
# [9]	validation_0-rmse:84.51459	validation_1-rmse:75.55706
# [10]	validation_0-rmse:81.73585	validation_1-rmse:72.71189
# [11]	validation_0-rmse:79.07602	validation_1-rmse:69.99320
# [12]	validation_0-rmse:76.57363	validation_1-rmse:67.64985
# [13]	validation_0-rmse:74.26485	validation_1-rmse:65.74744
# [14]	validation_0-rmse:72.06383	validation_1-rmse:63.34083
# [15]	validation_0-rmse:70.03004	validation_1-rmse:61.95636
# [16]	validation_0-rmse:68.09164	validation_1-rmse:60.25923
# [17]	validation_0-rmse:66.26420	validation_1-rmse:58.65289
# [18]	validation_0-rmse:64.56560	validation_1-rmse:56.87885
# [19]	validation_0-rmse:62.90435	validation_1-rmse:55.40721
# [20]	validation_0-rmse:61.31632	validation_1-rmse:54.36584
# [21]	validation_0-rmse:59.91640	validation_1-rmse:52.72890
# [22]	validation_0-rmse:58.49178	validation_1-rmse:51.24826
# [23]	validation_0-rmse:57.21422	validation_1-rmse:50.00383
# [24]	validation_0-rmse:56.03790	validation_1-rmse:49.05733
# [25]	validation_0-rmse:54.85479	validation_1-rmse:48.14693
# [26]	validation_0-rmse:53.79931	validation_1-rmse:47.32502
# [27]	validation_0-rmse:52.78649	validation_1-rmse:46.32987
# [28]	validation_0-rmse:51.82683	validation_1-rmse:45.24716
# [29]	validation_0-rmse:50.88547	validation_1-rmse:44.82304
# [30]	validation_0-rmse:50.04095	validation_1-rmse:43.95428
# [31]	validation_0-rmse:49.24674	validation_1-rmse:43.43303
# [32]	validation_0-rmse:48.45334	validation_1-rmse:42.90941
# [33]	validation_0-rmse:47.74019	validation_1-rmse:42.33250
# [34]	validation_0-rmse:47.05641	validation_1-rmse:41.88058
# [35]	validation_0-rmse:46.46111	validation_1-rmse:41.18112
# [36]	validation_0-rmse:45.85581	validation_1-rmse:40.61481
# [37]	validation_0-rmse:45.21429	validation_1-rmse:40.13112
# [38]	validation_0-rmse:44.62804	validation_1-rmse:39.71966
# [39]	validation_0-rmse:44.07703	validation_1-rmse:39.40931
# [40]	validation_0-rmse:43.54669	validation_1-rmse:39.12178
# [41]	validation_0-rmse:43.07509	validation_1-rmse:38.81085
# [42]	validation_0-rmse:42.58035	validation_1-rmse:38.40434
# [43]	validation_0-rmse:42.18840	validation_1-rmse:38.19183
# [44]	validation_0-rmse:41.76922	validation_1-rmse:37.94742
# [45]	validation_0-rmse:41.37499	validation_1-rmse:37.61766
# [46]	validation_0-rmse:40.97153	validation_1-rmse:37.26443
# [47]	validation_0-rmse:40.56672	validation_1-rmse:37.00113
# [48]	validation_0-rmse:40.24710	validation_1-rmse:36.77294
# [49]	validation_0-rmse:39.95547	validation_1-rmse:36.53016
# [50]	validation_0-rmse:39.67964	validation_1-rmse:36.29949
# [51]	validation_0-rmse:39.34387	validation_1-rmse:36.07392
# [52]	validation_0-rmse:39.09292	validation_1-rmse:35.99244
# [53]	validation_0-rmse:38.78231	validation_1-rmse:35.81144
# [54]	validation_0-rmse:38.49401	validation_1-rmse:35.64201
# [55]	validation_0-rmse:38.21575	validation_1-rmse:35.41009
# [56]	validation_0-rmse:37.93965	validation_1-rmse:35.29037
# [57]	validation_0-rmse:37.72049	validation_1-rmse:35.25441
# [58]	validation_0-rmse:37.43981	validation_1-rmse:35.16378
# [59]	validation_0-rmse:37.14382	validation_1-rmse:34.95353
# [60]	validation_0-rmse:36.91287	validation_1-rmse:34.93413
# [61]	validation_0-rmse:36.69327	validation_1-rmse:34.86014
# [62]	validation_0-rmse:36.50110	validation_1-rmse:34.71797
# [63]	validation_0-rmse:36.31370	validation_1-rmse:34.64529
# [64]	validation_0-rmse:36.14282	validation_1-rmse:34.52315
# [65]	validation_0-rmse:35.96827	validation_1-rmse:34.45768
# [66]	validation_0-rmse:35.74976	validation_1-rmse:34.34273
# [67]	validation_0-rmse:35.54444	validation_1-rmse:34.28356
# [68]	validation_0-rmse:35.34662	validation_1-rmse:34.21664
# [69]	validation_0-rmse:35.19609	validation_1-rmse:34.10158
# [70]	validation_0-rmse:35.07543	validation_1-rmse:34.00036
# [71]	validation_0-rmse:34.91547	validation_1-rmse:33.89119
# [72]	validation_0-rmse:34.74728	validation_1-rmse:33.95606
# [73]	validation_0-rmse:34.59951	validation_1-rmse:33.85211
# [74]	validation_0-rmse:34.45694	validation_1-rmse:33.80887
# [75]	validation_0-rmse:34.27508	validation_1-rmse:33.78776
# [76]	validation_0-rmse:34.12674	validation_1-rmse:33.72582
# [77]	validation_0-rmse:33.99650	validation_1-rmse:33.59907
# [78]	validation_0-rmse:33.85384	validation_1-rmse:33.55413
# [79]	validation_0-rmse:33.70412	validation_1-rmse:33.51472
# [80]	validation_0-rmse:33.58107	validation_1-rmse:33.43824
# [81]	validation_0-rmse:33.46793	validation_1-rmse:33.34637
# [82]	validation_0-rmse:33.32292	validation_1-rmse:33.32726
# [83]	validation_0-rmse:33.16023	validation_1-rmse:33.30011
# [84]	validation_0-rmse:33.03078	validation_1-rmse:33.27254
# [85]	validation_0-rmse:32.93315	validation_1-rmse:33.21491
# [86]	validation_0-rmse:32.77606	validation_1-rmse:33.17734
# [87]	validation_0-rmse:32.65220	validation_1-rmse:33.16766
# [88]	validation_0-rmse:32.56908	validation_1-rmse:33.11394
# [89]	validation_0-rmse:32.43689	validation_1-rmse:33.06806
# [90]	validation_0-rmse:32.33552	validation_1-rmse:33.01172
# [91]	validation_0-rmse:32.24764	validation_1-rmse:32.98700
# [92]	validation_0-rmse:32.14281	validation_1-rmse:32.87112
# [93]	validation_0-rmse:32.04007	validation_1-rmse:32.84064
# [94]	validation_0-rmse:31.93728	validation_1-rmse:32.84446
# [95]	validation_0-rmse:31.84984	validation_1-rmse:32.84028
# [96]	validation_0-rmse:31.73284	validation_1-rmse:32.74687
# [97]	validation_0-rmse:31.62783	validation_1-rmse:32.73113
# [98]	validation_0-rmse:31.53626	validation_1-rmse:32.71911
# [99]	validation_0-rmse:31.37472	validation_1-rmse:32.74509
# [100]	validation_0-rmse:31.30163	validation_1-rmse:32.68134
# [101]	validation_0-rmse:31.17074	validation_1-rmse:32.66035
# [102]	validation_0-rmse:31.09595	validation_1-rmse:32.65769
# [103]	validation_0-rmse:30.97150	validation_1-rmse:32.61004
# [104]	validation_0-rmse:30.87947	validation_1-rmse:32.63175
# [105]	validation_0-rmse:30.76784	validation_1-rmse:32.61006
# [106]	validation_0-rmse:30.64878	validation_1-rmse:32.69964
# [107]	validation_0-rmse:30.56424	validation_1-rmse:32.69360
# [108]	validation_0-rmse:30.47310	validation_1-rmse:32.73628
# [109]	validation_0-rmse:30.39945	validation_1-rmse:32.71854
# [110]	validation_0-rmse:30.28729	validation_1-rmse:32.73997
# [111]	validation_0-rmse:30.22103	validation_1-rmse:32.74432
# [112]	validation_0-rmse:30.17406	validation_1-rmse:32.70877
# [113]	validation_0-rmse:30.12142	validation_1-rmse:32.70150
# [114]	validation_0-rmse:30.02917	validation_1-rmse:32.69987
# [115]	validation_0-rmse:29.91700	validation_1-rmse:32.66576
# [116]	validation_0-rmse:29.84701	validation_1-rmse:32.52917
# [117]	validation_0-rmse:29.78619	validation_1-rmse:32.51082
# [118]	validation_0-rmse:29.72343	validation_1-rmse:32.51847
# [119]	validation_0-rmse:29.62381	validation_1-rmse:32.50796
# [120]	validation_0-rmse:29.53899	validation_1-rmse:32.46523
# [121]	validation_0-rmse:29.49127	validation_1-rmse:32.44794
# [122]	validation_0-rmse:29.39334	validation_1-rmse:32.42976
# [123]	validation_0-rmse:29.32055	validation_1-rmse:32.32350
# [124]	validation_0-rmse:29.21930	validation_1-rmse:32.31585
# [125]	validation_0-rmse:29.16829	validation_1-rmse:32.28893
# [126]	validation_0-rmse:29.08785	validation_1-rmse:32.18768
# [127]	validation_0-rmse:29.03122	validation_1-rmse:32.09197
# [128]	validation_0-rmse:28.96465	validation_1-rmse:32.10239
# [129]	validation_0-rmse:28.85963	validation_1-rmse:32.09716
# [130]	validation_0-rmse:28.79538	validation_1-rmse:32.07619
# [131]	validation_0-rmse:28.76154	validation_1-rmse:32.07018
# [132]	validation_0-rmse:28.70842	validation_1-rmse:32.08541
# [133]	validation_0-rmse:28.62211	validation_1-rmse:32.06713
# [134]	validation_0-rmse:28.55821	validation_1-rmse:32.08891
# [135]	validation_0-rmse:28.46577	validation_1-rmse:32.12358
# [136]	validation_0-rmse:28.35732	validation_1-rmse:32.11682
# [137]	validation_0-rmse:28.27554	validation_1-rmse:32.05914
# [138]	validation_0-rmse:28.19462	validation_1-rmse:32.05205
# [139]	validation_0-rmse:28.15334	validation_1-rmse:32.08942
# [140]	validation_0-rmse:28.09984	validation_1-rmse:32.06186
# [141]	validation_0-rmse:28.03989	validation_1-rmse:32.07051
# [142]	validation_0-rmse:27.97370	validation_1-rmse:32.06253
# [143]	validation_0-rmse:27.93064	validation_1-rmse:32.08576
# [144]	validation_0-rmse:27.88461	validation_1-rmse:32.07340
# [145]	validation_0-rmse:27.84458	validation_1-rmse:32.07981
# [146]	validation_0-rmse:27.78665	validation_1-rmse:32.08859
# [147]	validation_0-rmse:27.72658	validation_1-rmse:32.08452
# [148]	validation_0-rmse:27.68007	validation_1-rmse:32.09105
# [149]	validation_0-rmse:27.61240	validation_1-rmse:32.11354
# [150]	validation_0-rmse:27.52724	validation_1-rmse:32.09137
# [151]	validation_0-rmse:27.46314	validation_1-rmse:32.07914
# [152]	validation_0-rmse:27.37906	validation_1-rmse:32.07943
# [153]	validation_0-rmse:27.34149	validation_1-rmse:32.06440
# [154]	validation_0-rmse:27.27820	validation_1-rmse:32.05329
# [155]	validation_0-rmse:27.19168	validation_1-rmse:32.05165
# [156]	validation_0-rmse:27.12840	validation_1-rmse:32.06656
# [157]	validation_0-rmse:27.07132	validation_1-rmse:32.06639
# [158]	validation_0-rmse:27.03940	validation_1-rmse:32.05174
# [159]	validation_0-rmse:26.98071	validation_1-rmse:32.05653
# [160]	validation_0-rmse:26.94650	validation_1-rmse:31.98637
# [161]	validation_0-rmse:26.87259	validation_1-rmse:32.00410
# [162]	validation_0-rmse:26.83416	validation_1-rmse:31.93054
# [163]	validation_0-rmse:26.79553	validation_1-rmse:31.90878
# [164]	validation_0-rmse:26.73179	validation_1-rmse:31.92173
# [165]	validation_0-rmse:26.68697	validation_1-rmse:31.91194
# [166]	validation_0-rmse:26.63206	validation_1-rmse:31.91400
# [167]	validation_0-rmse:26.55555	validation_1-rmse:31.87253
# [168]	validation_0-rmse:26.47907	validation_1-rmse:31.81163
# [169]	validation_0-rmse:26.38784	validation_1-rmse:31.84158
# [170]	validation_0-rmse:26.33075	validation_1-rmse:31.83847
# [171]	validation_0-rmse:26.28367	validation_1-rmse:31.86008
# [172]	validation_0-rmse:26.21920	validation_1-rmse:31.85884
# [173]	validation_0-rmse:26.18729	validation_1-rmse:31.86074
# [174]	validation_0-rmse:26.11533	validation_1-rmse:31.82713
# [175]	validation_0-rmse:26.04341	validation_1-rmse:31.82761
# [176]	validation_0-rmse:25.96624	validation_1-rmse:31.79638
# [177]	validation_0-rmse:25.88315	validation_1-rmse:31.76039
# [178]	validation_0-rmse:25.80849	validation_1-rmse:31.76235
# [179]	validation_0-rmse:25.74374	validation_1-rmse:31.75184
# [180]	validation_0-rmse:25.67747	validation_1-rmse:31.75697
# [181]	validation_0-rmse:25.63739	validation_1-rmse:31.79258
# [182]	validation_0-rmse:25.59555	validation_1-rmse:31.71859
# [183]	validation_0-rmse:25.53959	validation_1-rmse:31.71361
# [184]	validation_0-rmse:25.43721	validation_1-rmse:31.72683
# [185]	validation_0-rmse:25.37445	validation_1-rmse:31.74021
# [186]	validation_0-rmse:25.33387	validation_1-rmse:31.73446
# [187]	validation_0-rmse:25.28828	validation_1-rmse:31.73561
# [188]	validation_0-rmse:25.25956	validation_1-rmse:31.72928
# [189]	validation_0-rmse:25.16480	validation_1-rmse:31.69915
# [190]	validation_0-rmse:25.08349	validation_1-rmse:31.68552
# [191]	validation_0-rmse:25.04629	validation_1-rmse:31.67784
# [192]	validation_0-rmse:24.99218	validation_1-rmse:31.68404
# [193]	validation_0-rmse:24.96177	validation_1-rmse:31.66726
# [194]	validation_0-rmse:24.92428	validation_1-rmse:31.68334
# [195]	validation_0-rmse:24.88983	validation_1-rmse:31.61995
# [196]	validation_0-rmse:24.84466	validation_1-rmse:31.61191
# [197]	validation_0-rmse:24.78989	validation_1-rmse:31.57270
# [198]	validation_0-rmse:24.70368	validation_1-rmse:31.57666
# [199]	validation_0-rmse:24.64125	validation_1-rmse:31.54587
# [200]	validation_0-rmse:24.59937	validation_1-rmse:31.55315
# [201]	validation_0-rmse:24.56722	validation_1-rmse:31.51324
# [202]	validation_0-rmse:24.49709	validation_1-rmse:31.53388
# [203]	validation_0-rmse:24.45803	validation_1-rmse:31.54220
# [204]	validation_0-rmse:24.41924	validation_1-rmse:31.55076
# [205]	validation_0-rmse:24.40202	validation_1-rmse:31.54053
# [206]	validation_0-rmse:24.37405	validation_1-rmse:31.56109
# [207]	validation_0-rmse:24.34170	validation_1-rmse:31.51634
# [208]	validation_0-rmse:24.26549	validation_1-rmse:31.51631
# [209]	validation_0-rmse:24.22376	validation_1-rmse:31.51916
# [210]	validation_0-rmse:24.18057	validation_1-rmse:31.50971
# [211]	validation_0-rmse:24.14082	validation_1-rmse:31.50994
# [212]	validation_0-rmse:24.11226	validation_1-rmse:31.54298
# [213]	validation_0-rmse:24.07984	validation_1-rmse:31.56314
# [214]	validation_0-rmse:24.05577	validation_1-rmse:31.56490
# [215]	validation_0-rmse:23.99845	validation_1-rmse:31.54590
# [216]	validation_0-rmse:23.92708	validation_1-rmse:31.54627
# [217]	validation_0-rmse:23.90407	validation_1-rmse:31.54879
# [218]	validation_0-rmse:23.85787	validation_1-rmse:31.54798
# [219]	validation_0-rmse:23.81627	validation_1-rmse:31.56890
# [220]	validation_0-rmse:23.73904	validation_1-rmse:31.60958
# [221]	validation_0-rmse:23.71884	validation_1-rmse:31.58784
# [222]	validation_0-rmse:23.66087	validation_1-rmse:31.60008
# [223]	validation_0-rmse:23.61672	validation_1-rmse:31.59895
# [224]	validation_0-rmse:23.56020	validation_1-rmse:31.53717
# [225]	validation_0-rmse:23.52444	validation_1-rmse:31.53472
# [226]	validation_0-rmse:23.48454	validation_1-rmse:31.55336
# [227]	validation_0-rmse:23.44324	validation_1-rmse:31.55979
# [228]	validation_0-rmse:23.40060	validation_1-rmse:31.56780
# [229]	validation_0-rmse:23.34237	validation_1-rmse:31.57532
# [230]	validation_0-rmse:23.26050	validation_1-rmse:31.53605
# [231]	validation_0-rmse:23.20511	validation_1-rmse:31.53309
# [232]	validation_0-rmse:23.18591	validation_1-rmse:31.52693
# [233]	validation_0-rmse:23.15501	validation_1-rmse:31.52628
# [234]	validation_0-rmse:23.11649	validation_1-rmse:31.47343
# [235]	validation_0-rmse:23.04423	validation_1-rmse:31.47719
# [236]	validation_0-rmse:22.98596	validation_1-rmse:31.44853
# [237]	validation_0-rmse:22.93341	validation_1-rmse:31.43630
# [238]	validation_0-rmse:22.89953	validation_1-rmse:31.46408
# [239]	validation_0-rmse:22.86082	validation_1-rmse:31.46574
# [240]	validation_0-rmse:22.81425	validation_1-rmse:31.53321
# [241]	validation_0-rmse:22.78894	validation_1-rmse:31.49243
# [242]	validation_0-rmse:22.76641	validation_1-rmse:31.48021
# [243]	validation_0-rmse:22.73873	validation_1-rmse:31.48475
# [244]	validation_0-rmse:22.67518	validation_1-rmse:31.50451
# [245]	validation_0-rmse:22.62892	validation_1-rmse:31.50547
# [246]	validation_0-rmse:22.59321	validation_1-rmse:31.50625
# [247]	validation_0-rmse:22.55801	validation_1-rmse:31.50585
# [248]	validation_0-rmse:22.53909	validation_1-rmse:31.49901
# [249]	validation_0-rmse:22.49244	validation_1-rmse:31.47698
# [250]	validation_0-rmse:22.45316	validation_1-rmse:31.45311
# [251]	validation_0-rmse:22.39768	validation_1-rmse:31.43007
# [252]	validation_0-rmse:22.36712	validation_1-rmse:31.43017
# [253]	validation_0-rmse:22.31472	validation_1-rmse:31.42187
# [254]	validation_0-rmse:22.25774	validation_1-rmse:31.42734
# [255]	validation_0-rmse:22.21917	validation_1-rmse:31.42872
# [256]	validation_0-rmse:22.17586	validation_1-rmse:31.43740
# [257]	validation_0-rmse:22.14325	validation_1-rmse:31.41842
# [258]	validation_0-rmse:22.09264	validation_1-rmse:31.41497
# [259]	validation_0-rmse:22.05792	validation_1-rmse:31.42833
# [260]	validation_0-rmse:22.02197	validation_1-rmse:31.44892
# [261]	validation_0-rmse:21.97823	validation_1-rmse:31.46426
# [262]	validation_0-rmse:21.96523	validation_1-rmse:31.43995
# [263]	validation_0-rmse:21.93113	validation_1-rmse:31.43450
# [264]	validation_0-rmse:21.91659	validation_1-rmse:31.43833
# [265]	validation_0-rmse:21.88841	validation_1-rmse:31.45474
# [266]	validation_0-rmse:21.86409	validation_1-rmse:31.47352
# [267]	validation_0-rmse:21.80217	validation_1-rmse:31.47743
# [268]	validation_0-rmse:21.77421	validation_1-rmse:31.46188
# [269]	validation_0-rmse:21.73944	validation_1-rmse:31.47144
# [270]	validation_0-rmse:21.69024	validation_1-rmse:31.44775
# [271]	validation_0-rmse:21.67173	validation_1-rmse:31.44593
# [272]	validation_0-rmse:21.62386	validation_1-rmse:31.43855
# [273]	validation_0-rmse:21.58677	validation_1-rmse:31.43801
# [274]	validation_0-rmse:21.55909	validation_1-rmse:31.43996
# [275]	validation_0-rmse:21.50958	validation_1-rmse:31.45768
# [276]	validation_0-rmse:21.48662	validation_1-rmse:31.46089
# [277]	validation_0-rmse:21.44783	validation_1-rmse:31.43219
# [278]	validation_0-rmse:21.43037	validation_1-rmse:31.42235
# [279]	validation_0-rmse:21.41076	validation_1-rmse:31.42258
# [280]	validation_0-rmse:21.38260	validation_1-rmse:31.43226
# [281]	validation_0-rmse:21.34413	validation_1-rmse:31.44895
# [282]	validation_0-rmse:21.29885	validation_1-rmse:31.45974
# [283]	validation_0-rmse:21.26203	validation_1-rmse:31.47496
# [284]	validation_0-rmse:21.24339	validation_1-rmse:31.48288
# [285]	validation_0-rmse:21.22922	validation_1-rmse:31.48996
# [286]	validation_0-rmse:21.18106	validation_1-rmse:31.47769
# [287]	validation_0-rmse:21.15261	validation_1-rmse:31.48042
# [288]	validation_0-rmse:21.10988	validation_1-rmse:31.49529
# [289]	validation_0-rmse:21.07268	validation_1-rmse:31.47120
# [290]	validation_0-rmse:21.03354	validation_1-rmse:31.45232
# [291]	validation_0-rmse:21.00129	validation_1-rmse:31.46184
# [292]	validation_0-rmse:20.97514	validation_1-rmse:31.46177
# [293]	validation_0-rmse:20.93365	validation_1-rmse:31.47039
# [294]	validation_0-rmse:20.88458	validation_1-rmse:31.46320
# [295]	validation_0-rmse:20.84908	validation_1-rmse:31.46259
# [296]	validation_0-rmse:20.82229	validation_1-rmse:31.46814
# [297]	validation_0-rmse:20.78681	validation_1-rmse:31.46772
# [298]	validation_0-rmse:20.73219	validation_1-rmse:31.46856
# [299]	validation_0-rmse:20.70101	validation_1-rmse:31.47272
# [300]	validation_0-rmse:20.65803	validation_1-rmse:31.45917
# [301]	validation_0-rmse:20.62484	validation_1-rmse:31.44593
# [302]	validation_0-rmse:20.58492	validation_1-rmse:31.44866
# [303]	validation_0-rmse:20.55840	validation_1-rmse:31.45109
# [304]	validation_0-rmse:20.52038	validation_1-rmse:31.46432
# [305]	validation_0-rmse:20.49155	validation_1-rmse:31.44872
# [306]	validation_0-rmse:20.43619	validation_1-rmse:31.45271
# [307]	validation_0-rmse:20.42623	validation_1-rmse:31.47293
# [308]	validation_0-rmse:20.38393	validation_1-rmse:31.46439
# 2025-12-15 15:24:23 - train_model - INFO - Best iteration: 258
# 2025-12-15 15:24:23 - train_model - INFO - Best score: 31.414969510271085

# %% [markdown]
# ## 5. Evaluate Model

# %%
# Evaluate on all sets
train_metrics = evaluate_model(model, X_train_scaled, y_train, set_name="Train")
val_metrics = evaluate_model(model, X_val_scaled, y_val, set_name="Validation")
test_metrics = evaluate_model(model, X_test_scaled, y_test, set_name="Test")
# Out:
# 2025-12-15 15:24:23 - train_model - INFO - Train Set Performance:
# 2025-12-15 15:24:23 - train_model - INFO -   MAE:  16.38 €/MWh
# 2025-12-15 15:24:23 - train_model - INFO -   RMSE: 22.09 €/MWh
# 2025-12-15 15:24:23 - train_model - INFO -   MAPE: inf%
# 2025-12-15 15:24:23 - train_model - INFO -   R²:   0.9679
# 2025-12-15 15:24:23 - train_model - INFO - Validation Set Performance:
# 2025-12-15 15:24:23 - train_model - INFO -   MAE:  22.71 €/MWh
# 2025-12-15 15:24:23 - train_model - INFO -   RMSE: 31.41 €/MWh
# 2025-12-15 15:24:23 - train_model - INFO -   MAPE: inf%
# 2025-12-15 15:24:23 - train_model - INFO -   R²:   0.2713
# 2025-12-15 15:24:23 - train_model - INFO - Test Set Performance:
# 2025-12-15 15:24:23 - train_model - INFO -   MAE:  28.79 €/MWh
# 2025-12-15 15:24:23 - train_model - INFO -   RMSE: 43.53 €/MWh
# 2025-12-15 15:24:23 - train_model - INFO -   MAPE: inf%
# 2025-12-15 15:24:23 - train_model - INFO -   R²:   0.4245

# %%
# Plot predictions vs actual
y_test_pred = model.predict(X_test_scaled)

# Create subplots
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=('Test Set: Actual vs Predicted Prices', 'Predicted vs Actual Scatter Plot'),
    vertical_spacing=0.12
)

# Time series plot
fig.add_trace(
    go.Scatter(x=y_test.index, y=y_test.values, name='Actual', 
               line=dict(color='blue', width=1.5), opacity=0.7),
    row=1, col=1
)
fig.add_trace(
    go.Scatter(x=y_test.index, y=y_test_pred, name='Predicted', 
               line=dict(color='red', width=1.5), opacity=0.7),
    row=1, col=1
)

# Scatter plot
fig.add_trace(
    go.Scatter(x=y_test.values, y=y_test_pred, mode='markers',
               marker=dict(color='blue', size=4, opacity=0.5),
               name='Predictions', showlegend=False),
    row=2, col=1
)

# Add perfect prediction line
min_val, max_val = y_test.min(), y_test.max()
fig.add_trace(
    go.Scatter(x=[min_val, max_val], y=[min_val, max_val],
               mode='lines', line=dict(color='red', dash='dash', width=2),
               name='Perfect Prediction', showlegend=False),
    row=2, col=1
)

# Update axes
fig.update_xaxes(title_text="Date", row=1, col=1)
fig.update_yaxes(title_text="Price (€/MWh)", row=1, col=1)
fig.update_xaxes(title_text="Actual Price (€/MWh)", row=2, col=1)
fig.update_yaxes(title_text="Predicted Price (€/MWh)", row=2, col=1)

fig.update_layout(height=800, showlegend=True)
fig.show()

# %%
# Error distribution and residual plot
errors = y_test.values - y_test_pred

fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Error Distribution', 'Residual Plot'),
    horizontal_spacing=0.12
)

# Histogram of errors
fig.add_trace(
    go.Histogram(x=errors, nbinsx=50, name='Errors',
                 marker=dict(color='steelblue', line=dict(color='black', width=1))),
    row=1, col=1
)

# Add vertical line at 0
fig.add_vline(x=0, line_dash="dash", line_color="red", line_width=2, row=1, col=1)

# Residual scatter plot
fig.add_trace(
    go.Scatter(x=y_test_pred, y=errors, mode='markers',
               marker=dict(color='steelblue', size=4, opacity=0.5),
               name='Residuals', showlegend=False),
    row=1, col=2
)

# Add horizontal line at 0
fig.add_hline(y=0, line_dash="dash", line_color="red", line_width=2, row=1, col=2)

# Update axes
fig.update_xaxes(title_text="Prediction Error (€/MWh)", row=1, col=1)
fig.update_yaxes(title_text="Frequency", row=1, col=1)
fig.update_xaxes(title_text="Predicted Price (€/MWh)", row=1, col=2)
fig.update_yaxes(title_text="Prediction Error (€/MWh)", row=1, col=2)

fig.update_layout(height=400, showlegend=False)
fig.show()

# %% [markdown]
# ## 6. Feature Importance

# %%
# Get top features
feature_importance = get_feature_importance(
    model,
    X_train.columns.tolist(),
    top_n=20
)

print("Top 20 Most Important Features:")
print(feature_importance)
# Out:
# Top 20 Most Important Features:
#                    feature  importance
# 24             price_lag_1    0.329219
# 35     price_rolling_6_max    0.207341
# 25             price_lag_2    0.090214
# 32    price_rolling_6_mean    0.083647
# 29            price_lag_24    0.035629
# 30            price_lag_48    0.027029
# 44  price_rolling_168_mean    0.016180
# 8          day_of_week_cos    0.015884
# 43    price_rolling_24_max    0.013094
# 23    load_forecast_future    0.010674
# 31           price_lag_168    0.007301
# 10               month_cos    0.006823
# 34     price_rolling_6_min    0.006760
# 57          price_diff_24h    0.006218
# 5                 hour_sin    0.006128
# 6                 hour_cos    0.005402
# 20    residual_load_x_hour    0.005304
# 47   price_rolling_168_max    0.004765
# 7          day_of_week_sin    0.004658
# 4                    solar    0.004607

# %%
# Plot feature importance
fig = go.Figure()

fig.add_trace(go.Bar(
    x=feature_importance['importance'].values,
    y=feature_importance['feature'].values,
    orientation='h',
    marker=dict(color='steelblue')
))

fig.update_layout(
    title='Top 20 Feature Importance',
    xaxis_title='Importance',
    yaxis_title='Feature',
    height=600,
    yaxis=dict(autorange='reversed')  # Highest importance at top
)

fig.show()

# %% [markdown]
# ## 7. Save Model

# %%
# Save trained model and feature engine
save_model(
    model,
    feature_engine,
    save_dir="../models",
    model_name="xgboost_24h_forecast"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Save trained model and feature engine
# ----> 2 save_model(
#       3     model,
#       4     feature_engine,
#       5     save_dir="../models",
#       6     model_name="xgboost_24h_forecast"
#       7 )
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/AI/Projects/ElectricityPriceForecasterNL/notebooks/../src/models/train.py:227, in save_model(model, feature_engine, save_dir, model_name)
#     225 # Save XGBoost model
#     226 model_path = save_path / f"{model_name}.json"
# --> 227 model.save_model(str(model_path))
#     228 logger.info(f"Model saved to: {model_path}")
#     230 # Save feature engine
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/AI/Projects/ElectricityPriceForecasterNL/.venv/lib/python3.12/site-packages/xgboost/sklearn.py:1113, in XGBModel.save_model(self, fname)
#    1111 meta: Dict[str, Any] = {}
#    1112 # For validation.
# -> 1113 meta["_estimator_type"] = self._get_type()
#    1114 meta_str = json.dumps(meta)
#    1115 self.get_booster().set_attr(scikit_learn=meta_str)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/AI/Projects/ElectricityPriceForecasterNL/.venv/lib/python3.12/site-packages/xgboost/sklearn.py:1104, in XGBModel._get_type(self)
#    1102 def _get_type(self) -> str:
#    1103     if not hasattr(self, "_estimator_type"):
# -> 1104         raise TypeError(
#    1105             "`_estimator_type` undefined.  "
#    1106             "Please use appropriate mixin to define estimator type."
#    1107         )
#    1108     return self._estimator_type
#
# TypeError: `_estimator_type` undefined.  Please use appropriate mixin to define estimator type.

# %% [markdown]
# ## 8. Model Insights

# %%
# Analyze errors by hour of day
error_by_hour = pd.DataFrame({
    'hour': y_test.index.hour,
    'error': np.abs(errors)
}).groupby('hour')['error'].mean()

fig = go.Figure()

fig.add_trace(go.Bar(
    x=error_by_hour.index,
    y=error_by_hour.values,
    marker=dict(color='steelblue')
))

fig.update_layout(
    title='Forecast Error by Hour of Day',
    xaxis_title='Hour of Day',
    yaxis_title='Mean Absolute Error (€/MWh)',
    height=400,
    showlegend=False
)

fig.show()

# %%
# Metrics comparison across train/val/test sets
metrics_df = pd.DataFrame({
    'Train': train_metrics,
    'Validation': val_metrics,
    'Test': test_metrics
})

# Plot metrics comparison
fig = go.Figure()

for metric in ['MAE', 'RMSE']:
    fig.add_trace(go.Bar(
        name=metric,
        x=['Train', 'Validation', 'Test'],
        y=metrics_df.loc[metric],
    ))

fig.update_layout(
    title='Model Performance Across Sets',
    xaxis_title='Dataset',
    yaxis_title='Error (€/MWh)',
    barmode='group',
    height=400
)

fig.show()

# %%
# Summary statistics
print("\n" + "="*60)
print("MODEL SUMMARY")
print("="*60)
print(f"\nForecast Horizon: 24 hours")
print(f"Training Samples: {len(X_train)}")
print(f"Validation Samples: {len(X_val)}")
print(f"Test Samples: {len(X_test)}")
print(f"\nNumber of Features: {X_train.shape[1]}")
print(f"Best Iteration: {model.best_iteration}")
print(f"\nTest Set Performance:")
print(f"  MAE:  {test_metrics['MAE']:.2f} €/MWh")
print(f"  RMSE: {test_metrics['RMSE']:.2f} €/MWh")
print(f"  MAPE: {test_metrics['MAPE']:.2f}%")
print(f"  R²:   {test_metrics['R2']:.4f}")
